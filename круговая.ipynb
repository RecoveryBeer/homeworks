# %%
import matplotlib.pyplot as plt
amount = [32, 10, 19, 19, 20]
labels = ["играю в баскетбол", "играю в волейбол", "играю в футбол", "играю в теннис", "играю во все"]

plt.pie(amount, labels=labels, autopct='%1.f%%')
plt.title("Распределение студентов по группам")
plt.show()
