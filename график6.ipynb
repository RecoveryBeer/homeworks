# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure()
plt.plot(x, 3/4*x**2/3 + np.sqrt(1-x**2), linestyle='--')
plt.show()
# Out:
# C:\Users\gggro\AppData\Local\Temp\ipykernel_3544\686567610.py:5: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, 3/4*x**2/3 + np.sqrt(1-x**2), linestyle='--')
